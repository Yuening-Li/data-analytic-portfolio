# %% [markdown]
# # BINARY CLASSIFIER

# %%
import combinations
import combinator
import review_classifier
import review_classifier_evaluate as evaluate
import textblob

# %%
cfgs = evaluate.get_combined_cfgs_journal_version()
evaluate.run_bin_classifier("Bug", cfgs, "_tt")
# Out:
# read data
# looking for file data/Bug_tt.json
# Load json data from json
# Training the Classifier (['Bug', 'Not_Bug'] Classifier)
# label: Bug
# P:0.7570093457943925, R:0.7363636363636363, F:0.7465437788018432
# label: Not_Bug
# P:0.7478260869565218, R:0.7678571428571429, F:0.7577092511013216
# Most Informative Features
#        contains(dropbox) = True              Bug : Not_Bu =     14.9 : 1.0
#         contains(freeze) = True              Bug : Not_Bu =     10.9 : 1.0
#             contains('s) = True              Bug : Not_Bu =     10.9 : 1.0
#                rating(1) = True           Not_Bu : Bug    =     10.7 : 1.0
#            contains('to) = True              Bug : Not_Bu =      9.6 : 1.0
#          contains('work) = True              Bug : Not_Bu =      9.6 : 1.0
#           contains(file) = True              Bug : Not_Bu =      8.9 : 1.0
#          contains('with) = True              Bug : Not_Bu =      8.3 : 1.0
# ...

# %%
evaluate.run_bin_classifier("Feature", cfgs, "_tt")
# Out:
# read data
# looking for file data/Feature_tt.json
# Load json data from json
# Training the Classifier (['Feature', 'Not_Feature'] Classifier)
# label: Feature
# P:0.8032786885245902, R:0.532608695652174, F:0.6405228758169935
# label: Not_Feature
# P:0.6532258064516129, R:0.8709677419354839, F:0.7465437788018432
# Most Informative Features
#           contains(also) = True           Featur : Not_Fe =      9.7 : 1.0
#            contains(add) = True           Featur : Not_Fe =      9.2 : 1.0
#          contains(crash) = True           Featur : Not_Fe =      8.6 : 1.0
#           contains(open) = True           Featur : Not_Fe =      8.6 : 1.0
#             contains(we) = True           Featur : Not_Fe =      7.9 : 1.0
#       contains(function) = True           Featur : Not_Fe =      7.1 : 1.0
#            contains(see) = True           Featur : Not_Fe =      7.0 : 1.0
#          contains(could) = True           Featur : Not_Fe =      6.9 : 1.0
# ...

# %%
evaluate.run_bin_classifier("Rating", cfgs, "_tt")
# Out:
# read data
# looking for file data/Rating_tt.json
# Load json data from json
# Training the Classifier (['Rating', 'Not_Rating'] Classifier)
# label: Rating
# P:0.6382978723404256, R:0.8411214953271028, F:0.7258064516129032
# label: Not_Rating
# P:0.7901234567901234, R:0.5565217391304348, F:0.6530612244897959
# Most Informative Features
#           contains(open) = True           Not_Ra : Rating =     16.2 : 1.0
#           contains(also) = True           Not_Ra : Rating =     12.7 : 1.0
#           contains(file) = True           Not_Ra : Rating =     10.0 : 1.0
#          contains(since) = True           Not_Ra : Rating =     10.0 : 1.0
#            contains(fix) = True           Not_Ra : Rating =      9.3 : 1.0
#            contains(try) = True           Not_Ra : Rating =      8.7 : 1.0
#        contains(picture) = True           Not_Ra : Rating =      7.9 : 1.0
#            contains(can) = True           Not_Ra : Rating =      7.7 : 1.0
# ...

# %%
evaluate.run_bin_classifier("UserExperience", cfgs, "_tt")
# Out:
# read data
# looking for file data/UserExperience_tt.json
# Load json data from json
# Training the Classifier (['UserExperience', 'Not_UserExperience'] Classifier)
# label: UserExperience
# P:0.8428571428571429, R:0.5363636363636364, F:0.6555555555555556
# label: Not_UserExperience
# P:0.6644736842105263, R:0.9017857142857143, F:0.7651515151515152
# Most Informative Features
#         contains(iphone) = True           UserEx : Not_Us =     11.6 : 1.0
#           contains('for) = True           UserEx : Not_Us =     10.9 : 1.0
#           contains(open) = True           Not_Us : UserEx =     10.4 : 1.0
#       contains(accurate) = True           UserEx : Not_Us =      8.3 : 1.0
#             contains(we) = True           UserEx : Not_Us =      7.6 : 1.0
#           contains(plan) = True           UserEx : Not_Us =      7.6 : 1.0
#           contains(load) = True           Not_Us : UserEx =      7.1 : 1.0
#           contains(ipad) = True           UserEx : Not_Us =      6.9 : 1.0
# ...

# %% [markdown]
# # MULTICLASS

# %%
evaluate.run_multiclass_ttdata(cfgs, "_tt")
# Out:
# read data
# looking for file data/Bug_tt.json
# Load json data from json
# read data
# looking for file data/Feature_tt.json
# Load json data from json
# read data
# looking for file data/UserExperience_tt.json
# Load json data from json
# read data
# looking for file data/Rating_tt.json
# Load json data from json
# multiclass version...
# filter Not_ Labels...
# Training the Classifier (['Bug', 'Feature', 'UserExperience', 'Rating'] Classifier)
# label: Bug
# P:0.7659574468085106, R:0.5625, F:0.6486486486486487
# label: Feature
# P:0.3333333333333333, R:0.1875, F:0.24000000000000005
# label: UserExperience
# P:0.5081967213114754, R:0.26495726495726496, F:0.348314606741573
# label: Rating
# P:0.36936936936936937, R:0.845360824742268, F:0.5141065830721002
# Most Informative Features
#           contains(open) = True              Bug : Rating =     26.7 : 1.0
#           contains(easy) = True           UserEx : Bug    =     23.3 : 1.0
# ...
