# %%
import combinator
import combinations

# %%
import review_classifier_evaluate as evaluate
cfgs = evaluate.get_combined_cfgs_journal_version()

# %%
import review_classifier
import review_classifier_evaluate

# %%
review_classifier_evaluate.run_bin_classifier("Bug",cfgs,"_tt")
review_classifier_evaluate.run_bin_classifier("Feature",cfgs,"_tt")
# Out:
# read data
# looking for file data/Bug_tt.json
# Load json data from json
# Training the Classifier (['Bug', 'Not_Bug'] Classifier)
# label: Bug
# P:0.8091286307053942, R:0.7116788321167883, F:0.7572815533980581
# label: Not_Bug
# P:0.8416833667334669, R:0.9012875536480687, F:0.8704663212435234
# Most Informative Features
#            contains(n't) = True              Bug : Not_Bu =     70.3 : 1.0
#             contains(ca) = True              Bug : Not_Bu =     24.9 : 1.0
#             contains('s) = True              Bug : Not_Bu =     18.3 : 1.0
#                rating(5) = True           Not_Bu : Bug    =     17.3 : 1.0
#         contains(latest) = True              Bug : Not_Bu =     17.1 : 1.0
#         contains(search) = True              Bug : Not_Bu =     14.9 : 1.0
#          contains(issue) = True              Bug : Not_Bu =     14.3 : 1.0
#            contains(let) = True              Bug : Not_Bu =     13.8 : 1.0
# ...
