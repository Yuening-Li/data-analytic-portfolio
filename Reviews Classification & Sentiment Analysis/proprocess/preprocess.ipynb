# %%
# %cd F:\UBC_Okanagan\Courses\DATA 542 Data Wrangling\data_542\project\drive-download-20191205T174359Z-001
# Out:
# F:\UBC_Okanagan\Courses\DATA 542 Data Wrangling\data_542\project\drive-download-20191205T174359Z-001

# %% [markdown]
# # Get Ready ... Initial Statistics.
# First, look at the shared dataset. Investigate the structure of the collected data, the files and folders. The timing of the collected data. Make yourself familiar with the data you want to analyze.

# %%
import pandas as pd

# %% [markdown]
# Import and read app reviews csv files

# %%
#read in all app reviews csv files
#1-8 3/13
data_review_edu = pd.read_csv("./2019-03-08_TOP_FREE_EDUCATION_APPS/2019-03-08_newest_reviews_TOP_FREE_EDUCATION_apps.csv")
data_review_edu["category"] = "EDUCATION"
data_review_edu["new_date"] = "2019-03-08"
data_review_finance = pd.read_csv("./2019-03-08_TOP_FREE_FINANCE_APPS/2019-03-08_newest_reviews_TOP_FREE_FINANCE_apps.csv")
data_review_finance["category"] = "FINANCE"
data_review_finance["new_date"] = "2019-03-08"
data_review_game = pd.read_csv("./2019-03-08_TOP_FREE_GAME_ACTION_APPS/2019-03-08_newest_reviews_TOP_FREE_GAME_ACTION_apps.csv")
data_review_game["category"] = "GAME_ACTION"
data_review_game["new_date"] = "2019-03-08"
data_review_music = pd.read_csv("./2019-03-09_TOP_FREE_MUSIC_AND_AUDIO_APPS/2019-03-09_newest_reviews_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
data_review_music["category"] = "MUSIC_AND_AUDIO"
data_review_music["new_date"] = "2019-03-08"
data_review_entertain = pd.read_csv("./2019-03-13_TOP_FREE_ENTERTAINMENT_APPS/2019-03-13_newest_reviews_TOP_FREE_ENTERTAINMENT_apps.csv")
data_review_entertain["category"] = "ENTERTAINMENT"
data_review_entertain["new_date"] = "2019-03-08"
data_review_family = pd.read_csv("./2019-03-13_TOP_FREE_FAMILY_APPS/2019-03-13_newest_reviews_TOP_FREE_FAMILY_apps.csv")
data_review_family["category"] = "FAMILY"
data_review_family["new_date"] = "2019-03-08"
data_review_lifestyle = pd.read_csv("./2019-03-13_TOP_FREE_LIFESTYLE_APPS/2019-03-13_newest_reviews_TOP_FREE_LIFESTYLE_apps.csv")
data_review_lifestyle["category"] = "LIFESTYLE"
data_review_lifestyle["new_date"] = "2019-03-08"
data_review_health = pd.read_csv("./2019-03-16_TOP_FREE_HEALTH_AND_FITNESS_APPS/2019-03-16_newest_reviews_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
data_review_health["category"] = "HEALTH_AND_FITNESS"
data_review_health["new_date"] = "2019-03-08"
# in folder 2019-03-24 
data_review_edu_f1 = pd.read_csv("./2019-03-24/2019-03-24_TOP_FREE_EDUCATION_APPS/2019-03-24_newest_reviews_TOP_FREE_EDUCATION_apps.csv")
data_review_edu_f1["category"] = "EDUCATION"
data_review_edu_f1["new_date"] = "2019-03-24"
data_review_entertain_f1 = pd.read_csv("./2019-03-24/2019-03-24_TOP_FREE_ENTERTAINMENT_APPS/2019-03-24_newest_reviews_TOP_FREE_ENTERTAINMENT_apps.csv")
data_review_entertain_f1["category"] = "ENTERTAINMENT"
data_review_entertain_f1["new_date"] = "2019-03-24"
data_review_family_f1 = pd.read_csv("./2019-03-24/2019-03-24_TOP_FREE_FAMILY_APPS/2019-03-24_newest_reviews_TOP_FREE_FAMILY_apps.csv")
data_review_family_f1["category"] = "FAMILY"
data_review_family_f1["new_date"] = "2019-03-24"
data_review_finance_f1 = pd.read_csv("./2019-03-24/2019-03-24_TOP_FREE_FINANCE_APPS/2019-03-24_newest_reviews_TOP_FREE_FINANCE_apps.csv")
data_review_finance_f1["category"] = "FINANCE"
data_review_finance_f1["new_date"] = "2019-03-24"
data_review_game_f1 = pd.read_csv("./2019-03-24/2019-03-24_TOP_FREE_GAME_ACTION_APPS/2019-03-24_newest_reviews_TOP_FREE_GAME_ACTION_apps.csv")
data_review_game_f1["category"] = "GAME_ACTION"
data_review_game_f1["new_date"] = "2019-03-24"
data_review_health_f1 = pd.read_csv("./2019-03-24/2019-03-24_TOP_FREE_HEALTH_AND_FITNESS_APPS/2019-03-24_newest_reviews_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
data_review_health_f1["category"] = "HEALTH_AND_FITNESS"
data_review_health_f1["new_date"] = "2019-03-24"
data_review_lifestyle_f1 = pd.read_csv("./2019-03-24/2019-03-24_TOP_FREE_LIFESTYLE_APPS/2019-03-24_newest_reviews_TOP_FREE_LIFESTYLE_apps.csv")
data_review_lifestyle_f1["category"] = "LIFESTYLE"
data_review_lifestyle_f1["new_date"] = "2019-03-24"
data_review_music_f1 = pd.read_csv("./2019-03-24/2019-03-24_TOP_FREE_MUSIC_AND_AUDIO_APPS/2019-03-24_newest_reviews_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
data_review_music_f1["category"] = "MUSIC_AND_AUDIO"
data_review_music_f1["new_date"] = "2019-03-24"
# 2019-04-01_TOP_FREE_categories
data_review_edu_f2 = pd.read_csv("./2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_EDUCATION_apps.csv")
data_review_edu_f2["category"] = "EDUCATION"
data_review_edu_f2["new_date"] = "2019-04-01"
data_review_entertain_f2 = pd.read_csv("./2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_ENTERTAINMENT_apps.csv")
data_review_entertain_f2["category"] = "ENTERTAINMENT"
data_review_entertain_f2["new_date"] = "2019-04-01"
data_review_family_f2 = pd.read_csv("./2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_FAMILY_apps.csv")
data_review_family_f2["category"] = "FAMILY"
data_review_family_f2["new_date"] = "2019-04-01"
data_review_finance_f2 = pd.read_csv("./2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_FINANCE_apps.csv")
data_review_finance_f2["category"] = "FINANCE"
data_review_finance_f2["new_date"] = "2019-04-01"
data_review_game_f2 = pd.read_csv("./2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_GAME_ACTION_apps.csv")
data_review_game_f2["category"] = "GAME_ACTION"
data_review_game_f2["new_date"] = "2019-04-01"
data_review_health_f2 = pd.read_csv("./2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
data_review_health_f2["category"] = "HEALTH_AND_FITNESS"
data_review_health_f2["new_date"] = "2019-04-01"
data_review_lifestyle_f2 = pd.read_csv("./2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_LIFESTYLE_apps.csv")
data_review_lifestyle_f2["category"] = "LIFESTYLE"
data_review_lifestyle_f2["new_date"] = "2019-04-01"
data_review_music_f2 = pd.read_csv("./2019-04-01_TOP_FREE_categories/2019-04-01_newest_reveiws_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
data_review_music_f2["category"] = "MUSIC_AND_AUDIO"
data_review_music_f2["new_date"] = "2019-04-01"
# 2019-04-07_TOP_FREE_category_apps
data_review_edu_f3 = pd.read_csv("./2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_EDUCATION_apps.csv")
data_review_edu_f3["category"] = "EDUCATION"
data_review_edu_f3["new_date"] = "2019-04-07"
data_review_entertain_f3 = pd.read_csv("./2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_ENTERTAINMENT_apps.csv")
data_review_entertain_f3["category"] = "ENTERTAINMENT"
data_review_entertain_f3["new_date"] = "2019-04-07"
data_review_family_f3 = pd.read_csv("./2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_FAMILY_apps.csv")
data_review_family_f3["category"] = "FAMILY"
data_review_family_f3["new_date"] = "2019-04-07"
data_review_finance_f3 = pd.read_csv("./2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_FINANCE_apps.csv")
data_review_finance_f3["category"] = "FINANCE"
data_review_finance_f3["new_date"] = "2019-04-07"
data_review_game_f3 = pd.read_csv("./2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_GAME_ACTION_apps.csv")
data_review_game_f3["category"] = "GAME_ACTION"
data_review_game_f3["new_date"] = "2019-04-07"
data_review_health_f3 = pd.read_csv("./2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
data_review_health_f3["category"] = "HEALTH_AND_FITNESS"
data_review_health_f3["new_date"] = "2019-04-07"
data_review_lifestyle_f3 = pd.read_csv("./2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_LIFESTYLE_apps.csv")
data_review_lifestyle_f3["category"] = "LIFESTYLE"
data_review_lifestyle_f3["new_date"] = "2019-04-07"
data_review_music_f3 = pd.read_csv("./2019-04-07_TOP_FREE_category_apps/2019-04-01_newest_reveiws_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
data_review_music_f3["category"] = "MUSIC_AND_AUDIO"
data_review_music_f3["new_date"] = "2019-04-07"
#2019-04-14_TOP_FREE_category_apps
data_review_edu_f4 = pd.read_csv("./2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_EDUCATION_apps.csv")
data_review_edu_f4["category"] = "EDUCATION"
data_review_edu_f4["new_date"] = "2019-04-14"
data_review_entertain_f4 = pd.read_csv("./2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_ENTERTAINMENT_apps.csv")
data_review_entertain_f4["category"] = "ENTERTAINMENT"
data_review_entertain_f4["new_date"] = "2019-04-14"
data_review_family_f4 = pd.read_csv("./2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_FAMILY_apps.csv")
data_review_family_f4["category"] = "FAMILY"
data_review_family_f4["new_date"] = "2019-04-14"
data_review_finance_f4 = pd.read_csv("./2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_FINANCE_apps.csv")
data_review_finance_f4["category"] = "FINANCE"
data_review_finance_f4["new_date"] = "2019-04-14"
data_review_game_f4 = pd.read_csv("./2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_GAME_ACTION_apps.csv")
data_review_game_f4["category"] = "GAME_ACTION"
data_review_game_f4["new_date"] = "2019-04-14"
data_review_health_f4 = pd.read_csv("./2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
data_review_health_f4["category"] = "HEALTH_AND_FITNESS"
data_review_health_f4["new_date"] = "2019-04-14"
data_review_lifestyle_f4 = pd.read_csv("./2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_LIFESTYLE_apps.csv")
data_review_lifestyle_f4["category"] = "LIFESTYLE"
data_review_lifestyle_f4["new_date"] = "2019-04-14"
data_review_music_f4 = pd.read_csv("./2019-04-14_TOP_FREE_category_apps/2019-04-14_newest_reveiws_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
data_review_music_f4["category"] = "MUSIC_AND_AUDIO"
data_review_music_f4["new_date"] = "2019-04-14"
# 2019-04-21_TOP_FREE_category_apps
data_review_edu_f5 = pd.read_csv("./2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_EDUCATION_apps.csv")
data_review_edu_f5["category"] = "EDUCATION"
data_review_edu_f5["new_date"] = "2019-04-21"
data_review_entertain_f5 = pd.read_csv("./2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_ENTERTAINMENT_apps.csv")
data_review_entertain_f5["category"] = "ENTERTAINMENT"
data_review_entertain_f5["new_date"] = "2019-04-21"
data_review_family_f5 = pd.read_csv("./2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_FAMILY_apps.csv")
data_review_family_f5["category"] = "FAMILY"
data_review_family_f5["new_date"] = "2019-04-21"
data_review_finance_f5 = pd.read_csv("./2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_FINANCE_apps.csv")
data_review_finance_f5["category"] = "FINANCE"
data_review_finance_f5["new_date"] = "2019-04-21"
data_review_game_f5 = pd.read_csv("./2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_GAME_ACTION_apps.csv")
data_review_game_f5["category"] = "GAME_ACTION"
data_review_game_f5["new_date"] = "2019-04-21"
data_review_health_f5 = pd.read_csv("./2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
data_review_health_f5["category"] = "HEALTH_AND_FITNESS"
data_review_health_f5["new_date"] = "2019-04-21"
data_review_lifestyle_f5 = pd.read_csv("./2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_LIFESTYLE_apps.csv")
data_review_lifestyle_f5["category"] = "LIFESTYLE"
data_review_lifestyle_f5["new_date"] = "2019-04-21"
data_review_music_f5 = pd.read_csv("./2019-04-21_TOP_FREE_category_apps/2019-04-21_newest_reveiws_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
data_review_music_f5["category"] = "MUSIC_AND_AUDIO"
data_review_music_f5["new_date"] = "2019-04-21"
# 2019-05-01_TOP_FREE_category_apps
data_review_edu_f6 = pd.read_csv("./2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_EDUCATION_apps.csv")
data_review_edu_f6["category"] = "EDUCATION"
data_review_edu_f6["new_date"] = "2019-05-01"
data_review_entertain_f6 = pd.read_csv("./2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_ENTERTAINMENT_apps.csv")
data_review_entertain_f6["category"] = "ENTERTAINMENT"
data_review_entertain_f6["new_date"] = "2019-05-01"
data_review_family_f6 = pd.read_csv("./2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_FAMILY_apps.csv")
data_review_family_f6["category"] = "FAMILY"
data_review_family_f6["new_date"] = "2019-05-01"
data_review_finance_f6 = pd.read_csv("./2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_FINANCE_apps.csv")
data_review_finance_f6["category"] = "FINANCE"
data_review_finance_f6["new_date"] = "2019-05-01"
data_review_game_f6 = pd.read_csv("./2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_GAME_ACTION_apps.csv")
data_review_game_f6["category"] = "GAME_ACTION"
data_review_game_f6["new_date"] = "2019-05-01"
data_review_health_f6= pd.read_csv("./2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
data_review_health_f6["category"] = "HEALTH_AND_FITNESS"
data_review_health_f6["new_date"] = "2019-05-01"
data_review_lifestyle_f6= pd.read_csv("./2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_LIFESTYLE_apps.csv")
data_review_lifestyle_f6["category"] = "LIFESTYLE"
data_review_lifestyle_f6["new_date"] = "2019-05-01"
data_review_music_f6= pd.read_csv("./2019-05-01_TOP_FREE_category_apps/2019-05-01_newest_reveiws_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
data_review_music_f6["category"] = "MUSIC_AND_AUDIO"
data_review_music_f6["new_date"] = "2019-05-01"
# 2019-05-09_TOP_FREE_category_apps
data_review_edu_f7= pd.read_csv("./2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_EDUCATION_apps.csv")
data_review_edu_f7["category"] = "EDUCATION"
data_review_edu_f7["new_date"] = "2019-05-09"
data_review_entertain_f7 = pd.read_csv("./2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_ENTERTAINMENT_apps.csv")
data_review_entertain_f7["category"] = "ENTERTAINMENT"
data_review_entertain_f7["new_date"] = "2019-05-09"
data_review_family_f7 = pd.read_csv("./2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_FAMILY_apps.csv")
data_review_family_f7["category"] = "FAMILY"
data_review_family_f7["new_date"] = "2019-05-09"
data_review_finance_f7 = pd.read_csv("./2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_FINANCE_apps.csv")
data_review_finance_f7["category"] = "FINANCE"
data_review_finance_f7["new_date"] = "2019-05-09"
data_review_game_f7 = pd.read_csv("./2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_GAME_ACTION_apps.csv")
data_review_game_f7["category"] = "GAME_ACTION"
data_review_game_f7["new_date"] = "2019-05-09"
data_review_health_f7 = pd.read_csv("./2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_HEALTH_AND_FITNESS_apps.csv")
data_review_health_f7["category"] = "HEALTH_AND_FITNESS"
data_review_health_f7["new_date"] = "2019-05-09"
data_review_lifestyle_f7 = pd.read_csv("./2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_LIFESTYLE_apps.csv")
data_review_lifestyle_f7["category"] = "LIFESTYLE"
data_review_lifestyle_f7["new_date"] = "2019-05-09"
data_review_music_f7 = pd.read_csv("./2019-05-09_TOP_FREE_category_apps/2019-05-09_newest_reveiws_TOP_FREE_MUSIC_AND_AUDIO_apps.csv")
data_review_music_f7["category"] = "MUSIC_AND_AUDIO"
data_review_music_f7["new_date"] = "2019-05-09"

# %% [markdown]
# To start, combine all of the reviews files from all of the eight app categories together. These files are named as DATE_newest_reviews_TOP_FREE_CAT_NAME. The DATE shows different dates of the collected data and the CAT_NAME identifies one of the eight categories.

# %%
reviews = pd.concat([data_review_edu, data_review_finance,data_review_game,data_review_music,data_review_entertain,data_review_family,data_review_lifestyle,data_review_health, \
                    + data_review_edu_f1, data_review_finance_f1,data_review_game_f1,data_review_music_f1,data_review_entertain_f1,data_review_family_f1,data_review_lifestyle_f1,data_review_health_f1, \
                    + data_review_edu_f2, data_review_finance_f2,data_review_game_f2,data_review_music_f2,data_review_entertain_f2,data_review_family_f2,data_review_lifestyle_f2,data_review_health_f2, \
                     + data_review_edu_f3, data_review_finance_f3,data_review_game_f3,data_review_music_f3,data_review_entertain_f3,data_review_family_f3,data_review_lifestyle_f3,data_review_health_f3, \
                     + data_review_edu_f4, data_review_finance_f4,data_review_game_f4,data_review_music_f4,data_review_entertain_f4,data_review_family_f4,data_review_lifestyle_f4,data_review_health_f4, \
                     + data_review_edu_f5, data_review_finance_f5,data_review_game_f5,data_review_music_f5,data_review_entertain_f5,data_review_family_f5,data_review_lifestyle_f5,data_review_health_f5, \
                    + data_review_edu_f6, data_review_finance_f6,data_review_game_f6,data_review_music_f6,data_review_entertain_f6,data_review_family_f6,data_review_lifestyle_f6,data_review_health_f6, \
                    + data_review_edu_f7, data_review_finance_f7,data_review_game_f7,data_review_music_f7,data_review_entertain_f7,data_review_family_f7,data_review_lifestyle_f7,data_review_health_f7])

# %%
reviews.to_csv('reviews.csv',index="False")

# %%
reviews.shape
# Out:
# (2715303, 7)

# %% [markdown]
# 1. Drop duplicates and record how many unique reviews are collected?

# %%
# print(reviews.shape)
# reviews.groupby(['category']).count()
df = reviews.copy()
df["id"] = range(len(df.index))
df.drop_duplicates(subset= ["appTitle","userName","date","score","text","category"],inplace = True)
print(len(df.index))
# Out:
# 1478938

# %% [markdown]
# 2. How many unique apps are in the dataset? How many apps in each of the 8 specified app categories?

# %%
print("There are",df.appTitle.nunique(),"unique apps in the dataset")
df.groupby(["category"]).appTitle.nunique()
# Out:
# There are 87 unique apps in the dataset
# category
# EDUCATION             10
# ENTERTAINMENT         14
# FAMILY                10
# FINANCE               10
# GAME_ACTION           11
# HEALTH_AND_FITNESS    10
# LIFESTYLE             12
# MUSIC_AND_AUDIO       11
# Name: appTitle, dtype: int64

# %% [markdown]
# There are 10 unique apps in category EDUCATION, 14 unique apps in category Entertianment, 10 unique apps in category FAMILY, 10 unique apps in category FINANCE, 11 unique apps in category GAME_ACTION,10 unique apps in category HEALTH_AND_FITNESS, 12 unique app in category LIFESTYLE and 11 unique apps in MUSIC_AND_AUDIO.

# %% [markdown]
# 3. How many reviews exist in each of the eight app-categories?

# %%
print("Number of reviews in each of the eight app-categories:")
df.groupby(["category"]).text.count()
# Out:
# Number of reviews in each of the eight app-categories:
# category
# EDUCATION             137227
# ENTERTAINMENT         226711
# FAMILY                167172
# FINANCE               185473
# GAME_ACTION           252982
# HEALTH_AND_FITNESS    154321
# LIFESTYLE             137728
# MUSIC_AND_AUDIO       217228
# Name: text, dtype: int64

# %% [markdown]
# 4. Based on the contentRating column in the details files for each app, what are the different contentRating groups in each app-category?

# %% [markdown]
# import and read all of the csv files containing the details of the apps

# %%
import os
import glob
path = r'F:\UBC_Okanagan\Courses\DATA 542 Data Wrangling\data_542\project\drive-download-20191205T174359Z-001'
lst =[]
for root,dirs,_ in os.walk(path):
    for d in dirs:
        path_sub = os.path.join(root,d)
        for filename in glob.glob(os.path.join(path_sub, '*_all_detailed_TOP_FREE_*_apps.csv')):
            data = pd.read_csv(filename, encoding = "unicode-escape")
            lst.append(data)
details = pd.concat(lst,sort="True")
details.shape
# Out:
# (637, 58)

# %%
details.to_csv('details.csv',index="False")

# %%
data = details.copy()

# %%
# merge df with data['appTitle','countRating']
merge_data = data[['appTitle','contentRating']]
merge_data.head(10)
after_merge=df.merge(merge_data, how='left', on = "appTitle")

# %%
after_merge_withoutNA = after_merge.dropna()
print("The different contentRating groups in each app-category")
after_merge_withoutNA.groupby(["category"]).contentRating.unique()
# Out:
# The different contentRating groups in each app-category
# category
# EDUCATION                               [Everyone]
# ENTERTAINMENT         [Teen, Everyone, Mature 17+]
# FAMILY                    [Everyone 10+, Everyone]
# FINANCE                                 [Everyone]
# GAME_ACTION           [Everyone, Teen, Mature 17+]
# HEALTH_AND_FITNESS                      [Everyone]
# LIFESTYLE             [Everyone, Mature 17+, Teen]
# MUSIC_AND_AUDIO                   [Teen, Everyone]
# Name: contentRating, dtype: object

# %% [markdown]
# 5. How many apps exist in each of these contentRating-sub-groups in each app-category?

# %%
print("Number of apps in each of contentRating-sub groups in each app-category")
after_merge.groupby(["category","contentRating"])["appTitle"].nunique()
# Out:
# Number of apps in each of contentRating-sub groups in each app-category
# category            contentRating
# EDUCATION           Everyone         10
# ENTERTAINMENT       Everyone          4
#                     Mature 17+        1
#                     Teen              6
# FAMILY              Everyone          6
#                     Everyone 10+      3
# FINANCE             Everyone          9
# GAME_ACTION         Everyone          5
#                     Mature 17+        2
#                     Teen              4
# HEALTH_AND_FITNESS  Everyone         10
# LIFESTYLE           Everyone          9
#                     Mature 17+        1
#                     Teen              1
# MUSIC_AND_AUDIO     Everyone          2
#                     Teen              8
# Name: appTitle, dtype: int64

# %% [markdown]
# 6. How many reviews in each contentRating-sub-groups in each app-category?
#
# Here shows the number of reviews in the reviews dataframe

# %%
print("Number of reviews in each contentRating-sub-groups \n in each app-category")
after_merge.groupby(["category","contentRating"])["text"].count()
# Out:
# Number of reviews in each contentRating-sub-groups
#  in each app-category
# category            contentRating
# EDUCATION           Everyone         752316
# ENTERTAINMENT       Everyone          22588
#                     Mature 17+        43668
#                     Teen             757320
# FAMILY              Everyone         583878
#                     Everyone 10+     288642
# FINANCE             Everyone         802554
# GAME_ACTION         Everyone         525360
#                     Mature 17+       130791
#                     Teen             555444
# HEALTH_AND_FITNESS  Everyone         659154
# LIFESTYLE           Everyone         389192
#                     Mature 17+       130296
#                     Teen               3012
# MUSIC_AND_AUDIO     Everyone         136524
#                     Teen             785968
# Name: text, dtype: int64

# %% [markdown]
# ### Text Pre-processing.
# Apply the following on the text column.
# - Remove the non-English reviews.
# - Remove the non-ASCII characters.
# - Remove punctuations.
# - Remove multiple characters if they occur more than 2 times continuously. Check your results so that it does not change words such as HELLO that has 2 Ls.

# %% [markdown]
# #### Here we use two different ideas to remove non-english reviews. One is

# %%
# import nltk
# nltk.download('words')

# %%
import nltk
words = set(nltk.corpus.words.words())

# %%
import string
import re
df_try = reviews.copy()
df_try["id"] = range(len(df_try.index))
df_try.drop_duplicates(subset= ["appTitle","userName","date","score","text","category"],inplace = True)

df_try["text"] = df_try["text"].astype(str)
df_try["new_text"] = df_try["text"]
def clean_sent(sent):
    return " ".join(w for w in nltk.wordpunct_tokenize(sent) \
     if w.lower() in words or not w.isalpha())
def remove_non_ascii(s): return ''.join([i if 32 < ord(i) < 126 else " " for i in s])
def remove_punctuation(s): return ''.join([p for p in s if p not in string.punctuation])
def remove_multiple_chars(s): return re.sub(r'(.)\1+', r'\1\1', s)
new_comment_list =[]
for row in df_try.itertuples():
    each_text = getattr(row, "new_text")
    index = int(getattr(row, "id"))
    #   instead of checking if the row has non-english reviews, remove all words that are non-english, and if the whole sentence is non english, the wholse sentence would become "", and would be removed for less than two or less numbers
    remove_words = clean_sent(each_text)
    #remove the non-ascii characters
    non_ascii = remove_non_ascii(remove_words)
    #remove the punctuations
    non_punct = remove_punctuation(non_ascii)
    #remove more than 2 times continuously characters
    final_value= remove_multiple_chars(non_punct)
    new_comment_list.append(final_value)
df_try['new_text'] = new_comment_list
count = df_try['new_text'].str.split().str.len()
df_try =df_try[~(count<=2)]

# %%
import string
import re
df["text"] = df["text"].astype(str)
df["new_text"] = df["text"]
def has_non_english(sent):
    for w in nltk.wordpunct_tokenize(sent):
        if not(w.lower() in words or not w.isalpha()):
            return True # has non english words
    return False
def remove_non_ascii(s): return ''.join([i if 32 < ord(i) < 126 else " " for i in s])
def remove_punctuation(s): return ''.join([p for p in s if p not in string.punctuation])
def remove_multiple_chars(s): return re.sub(r'(.)\1+', r'\1\1', s)
remove_index = []
new_comment_list =[]
for row in df.itertuples():
    each_text = getattr(row, "new_text")
    index = int(getattr(row, "id"))
    # get all non-english reviews rows
    if(has_non_english(each_text)):
        remove_index.append(index)
    #remove the non-ascii characters
    non_ascii = remove_non_ascii(each_text)
    #remove the punctuations
    non_punct = remove_punctuation(non_ascii)
    #remove more than 2 times continuously characters
    final_value= remove_multiple_chars(non_punct)
    new_comment_list.append(final_value)
df['new_text'] = new_comment_list
df = df[~df['id'].isin(remove_index)]

# %% [markdown]
# 7. Should we remove the reviews that contain two or less number of words?
# a. Justify your answers.
# b. Can we remove the reviews with two or less words for some score-sub-groups and keep them in the other ones? E.g. if the review has score 1, we should remove such reviews, but we should keep them if the rating is 5. Justify your answers.

# %%
df_try.shape
df = df_try # WE DECIDE TO USE the former one, reason explained in report

# %% [markdown]
# a) Yes we should remove the reviews that contain two or less number of words. Because it would not provide any meaningful information if the lenth of the comment is too short.
#
# b) We should not only remove the reviews with two or less words for some score-sub-groups and keep them in the other ones. I think we should apply this to all scores-sub categories because the less than two words comment would always not being able to convey constructive suggestions no matter what scores-sub categories that comment is in.evaluations on the app.

# %% [markdown]
# - Remove the reviews that have two or less number of words.
#
# reviews that have two or less number of words ar removed in block 20

# %%
# count = df['new_text'].str.split().str.len()
# df = df[~(count<=2)]

# %%
df.shape
# Out:
# (927297, 9)

# %%
df.to_csv('preprocess.csv',index="False")

# %% [markdown]
# 8. How many reviews exist in each of the eight app-categories? Compare with question 3.

# %%
print("Number of reviews in each of the eight app-categories:")
df.groupby(["category"]).new_text.count()
# Out:
# Number of reviews in each of the eight app-categories:
# category
# EDUCATION              94680
# ENTERTAINMENT         126802
# FAMILY                113376
# FINANCE               123332
# GAME_ACTION           134985
# HEALTH_AND_FITNESS    107338
# LIFESTYLE              87963
# MUSIC_AND_AUDIO       138821
# Name: new_text, dtype: int64

# %%
# comparation
lst_before = [137227, 226711,167172,185473, 252982, 154321,137728, 217228]
lst_after = [94680,126802,113376,123332, 134985,107338,87963,138821]
ratio =[]
for i in range(len(lst_before)):
    r = lst_before[i]/lst_after[i]
    ratio.append(r)
print("For each category, the reviews drops in average ratio of 1/ %s of original reviews" %(sum(ratio)/len(ratio)))
# Out:
# For each category, the reviews drops in average ratio of 1/ 1.5822561390371601 of original reviews

# %% [markdown]
# From the comparision we could see that, the number of reviews in each of the eight app-category largely drops after we preprocess our data.

# %% [markdown]
# 9. How many reviews in each contentRating-sub-groups in each app-category? Compare with question 6.

# %%
merge_data = data[['appTitle','contentRating']]
after_merge=df.merge(merge_data, how='left', on = "appTitle")

# %%
after_merge.groupby(["category","contentRating"])["new_text"].count()
# Out:
# category            contentRating
# EDUCATION           Everyone         532158
# ENTERTAINMENT       Everyone          15499
#                     Mature 17+        28350
#                     Teen             395088
# FAMILY              Everyone         394686
#                     Everyone 10+     213276
# FINANCE             Everyone         520272
# GAME_ACTION         Everyone         317178
#                     Mature 17+        51305
#                     Teen             280380
# HEALTH_AND_FITNESS  Everyone         454074
# LIFESTYLE           Everyone         240946
#                     Mature 17+        83376
#                     Teen               2024
# MUSIC_AND_AUDIO     Everyone          91884
#                     Teen             492870
# Name: new_text, dtype: int64

# %%
# comparation
lst_before = [752316, 22588, 43668,757320,583878,288642,802554,525360,130791,555444,659154,389192,130296,  3012,136524,785968]
lst_after = [ 532158,  15499,  28350, 395088, 394686, 213276, 520272, 317178,  51305, 280380, 454074, 240946,  83376,   2024,  91884, 492870]
ratio =[]
for i in range(len(lst_before)):
    r = lst_before[i]/lst_after[i]
    ratio.append(r)
print("For each contentRating-sub-groups in each app-category, the reviews drops in average ratio of 1/ %s of original reviews" %(sum(ratio)/len(ratio)))
# Out:
# For each contentRating-sub-groups in each app-category, the reviews drops in average ratio of 1/ 1.630532989300242 of original reviews

# %% [markdown]
# The drop rate is about 60%.

# %% [markdown]
# ### Analyzing Each Category.
# ##### Analyze the following for each app-category.
# 10. What is the number of reviews for each score (score column)? For example, 35000 reviews have
# a score of 1, etc.

# %%
df.groupby(["category","score"]).new_text.count()
# Out:
# category            score
# EDUCATION           1         9279
#                     2         2395
#                     3         4493
#                     4        10452
#                     5        68061
# ENTERTAINMENT       1        19401
#                     2         5786
#                     3         8684
#                     4        16535
#                     5        76396
# FAMILY              1        12317
#                     2         3371
#                     3         5819
#                     4        12398
#                     5        79471
# FINANCE             1        26598
#                     2         4891
#                     3         4895
#                     4        10478
#                     5        76470
# GAME_ACTION         1        18604
#                     2         3883
#                     3         6504
#                     4        13514
#                     5        92480
# HEALTH_AND_FITNESS  1        19234
# ...

# %% [markdown]
# 11. How many apps exist in each score-sub-group?

# %%
df.groupby(["category","score"]).appTitle.nunique()
# Out:
# category            score
# EDUCATION           1        10
#                     2        10
#                     3        10
#                     4        10
#                     5        10
# ENTERTAINMENT       1        14
#                     2        14
#                     3        14
#                     4        14
#                     5        14
# FAMILY              1        10
#                     2        10
#                     3        10
#                     4        10
#                     5        10
# FINANCE             1        10
#                     2        10
#                     3        10
#                     4        10
#                     5        10
# GAME_ACTION         1        11
#                     2        11
#                     3        11
#                     4        11
#                     5        11
# HEALTH_AND_FITNESS  1        10
#                     2        10
#                     3        10
# ...

# %% [markdown]
# 12. Compare the number of reviews for each score in a plot (Remember to normalize the numbers when you are comparing them).
#
# Answered in last block, my anser sheet.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
score_reviews = df.groupby(["category","score"])
data_list =[None] * 5
count = 0
for category_subcategory, df_group in score_reviews:
    num_reviews = len(df_group)
    data_list[int(count % 5)] = num_reviews
    if(count!=0 and (count % 5)==4 ):
        #print(count,category_subcategory)
        #draw plots
        index = np.arange(len(data_list))
        #normalize
        total = data_list[0]+data_list[1]+data_list[2]+data_list[3]+data_list[4]
        data_list[0] = data_list[0]/total
        data_list[1] = data_list[1]/total
        data_list[2] = data_list[3]/total
        data_list[3] = data_list[3]/total
        data_list[4] = data_list[4]/total
        bar_width = 0.35
        opacity = 0.4
        error_config = {'ecolor': '0.3'}
        rects = plt.bar(index, data_list, bar_width, alpha=opacity,color='b', yerr=None, error_kw=error_config,label='score')
        plt.xlabel('score')
        plt.ylabel('number of reviews')
        plt.title(category_subcategory[0])
        plt.xticks(index, ('1', '2', '3', '4','5'))
        plt.legend()
        plt.tight_layout()
        plt.show()
    count = count + 1

# %% [markdown]
# From each plot, we could see the general trend for number of reviews for each score, The score 5 would have the most and far mrore number of reviews than other scores, the score 1 is always the second most and score 2 always the least.

# %% [markdown]
# 13. What is the average length of the reviews in each score-sub-group?

# %%
df.groupby(["category","score"])['new_text'].apply(lambda x: np.mean(x.str.len())).reset_index(name='mean_len_text')
# Out:
#               category  score  mean_len_text
# 0            EDUCATION      1      89.476237
# 1            EDUCATION      2     136.625052
# 2            EDUCATION      3     104.868239
# 3            EDUCATION      4      84.342135
# 4            EDUCATION      5      55.986248
# 5        ENTERTAINMENT      1      91.871295
# 6        ENTERTAINMENT      2     108.145524
# 7        ENTERTAINMENT      3      90.498733
# 8        ENTERTAINMENT      4      68.871001
# 9        ENTERTAINMENT      5      46.922352
# 10              FAMILY      1      85.575302
# 11              FAMILY      2     113.337585
# 12              FAMILY      3      98.227531
# 13              FAMILY      4      88.573318
# 14              FAMILY      5      56.847492
# 15             FINANCE      1     137.217986
# 16             FINANCE      2     129.417502
# 17             FINANCE      3     109.325638
# 18             FINANCE      4      69.696793
# 19             FINANCE      5      49.304302
# ...

# %% [markdown]
# 14. Compare the average length of reviews in each score-sub-group in the 8 app categories (draw a plot).
#
# Answered in last block, my anser sheet.

# %%
temp = df.copy()
temp["len"]= temp["new_text"].astype(str).apply(lambda x: len(x))

# %%
print("Average length of reviews in each score-sub-group in the 8 app categories")
df2 = temp.groupby(["category","score"])['len'].mean().unstack('category')
df2.plot(kind='bar', stacked=False).legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
# Out:
# Average length of reviews in each score-sub-group in the 8 app categories

# %% [markdown]
# Analysis: In this plot, we could see more clearly that the score 1, 2 and 3 tends to have onger reviews and score 5 tend to has shortest reviews. This is probabaly because people are more likely to complain aboout the app and leave constructive comments when they find issues raised in the app.
#
# And in terms of categories, we find that the health and fitness category have longest average length of review, and game action have shorttest average lenth review.

# %% [markdown]
# 15. Compare the number of reviews in each score-sub-group in the 8 app categories (draw a plot).
#
# Answered in last block, my anser sheet.

# %%
print("the number of reviews in each score-sub-group in the 8 app categories")
df3 = df.groupby(["category","score"]).new_text.count().unstack('category')
# df3 = df3.apply(lambda x: x/(df3.sum().sum()))
df3.plot(kind='bar', stacked=False).legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
# Out:
# the number of reviews in each score-sub-group in the 8 app categories

# %% [markdown]
# In terms of different categories, we find that the game action tends to have most numbers of higher score reviews, which is corresponding to the minimum length in the reviews from the previous finding. On the contrary, the lifestyle category tends to have the most number of low score reviews.
#
# And in terms of scores, we find that there are drastically far more 5 scores than the other scores reviews and 1 score numbers are also more than score2,3 and 4.

# %% [markdown]
# 16. Compare the number of apps in each score-sub-group in the 8 app categories (draw a plot).
# Hint: For the last three questions in this section, you don’t need to apply new analysis. Use the results of
# the previous questions in this section.
#
# Answered in last block, my anser sheet.

# %%
df4 = df.groupby(["category","score"]).appTitle.nunique().unstack('category')
df4.plot(kind='bar', stacked=False).legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)

# %% [markdown]
# ### Correlation Analysis.
# 17. Is there any correlation between the length of the reviews and the score in each app-category?
#
# Answered in last block, my anser sheet.

# %%
df["score"]=df["score"].astype(float)
temp = df.copy()
temp['len']=temp["new_text"].apply(lambda x: len(x))
func1 = lambda x: x.corrwith(x['len'], axis=0)
df6 = temp.groupby(['category']).apply(func1)["score"]
df6
# Out:
# category
# EDUCATION            -0.035877
# ENTERTAINMENT        -0.182429
# FAMILY               -0.083056
# FINANCE              -0.238424
# GAME_ACTION          -0.115056
# HEALTH_AND_FITNESS   -0.171490
# LIFESTYLE            -0.203694
# MUSIC_AND_AUDIO      -0.199926
# Name: score, dtype: float64

# %%
import seaborn as sns
corr = temp[['len','score']].corr()
# plot the heatmap
sns.heatmap(corr, xticklabels=corr.columns,yticklabels=corr.columns)

# %% [markdown]
# ### Date-time Analysis.
# 18. Find the evolution/changes of the star rating and length of reviews during time for each app
# category. Draw plots.
#
# Answered in last block, my anser sheet.
#
# a. Can we use the date column for this question?
#
# b. If not, what is the solution based on the data you have?

# %% [markdown]
# a) we cannot use the date column for this question, because the date in date column are not unify, it has date from different day, month or even year.
#
# b) from the data we have, we can extract the date from the filename as new_date and add as a column

# %%
df["new_date"] =pd.to_datetime(df['new_date'], format='%Y-%m-%d')
temp = df.copy()
temp['len']=temp["new_text"].apply(lambda x: len(x))
edu = temp[(temp.category == 'EDUCATION')].groupby(["new_date","score"])[['len']].mean().unstack('score')
p = edu.plot()
p.legend(('1','2','3','4','5'),loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
p.set_title('EDUCATION')
p.set_ylabel('Length of review')

ent = temp[(temp.category == 'ENTERTAINMENT')].groupby(["new_date","score"])[['len']].mean().unstack('score')
p= ent.plot()
p.legend(('1','2','3','4','5'),loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
p.set_title('ENTERTAINMENT')
p.set_ylabel('Length of review')

fam = temp[(temp.category == 'FAMILY')].groupby(["new_date","score"])[['len']].mean().unstack('score')
p= fam.plot()
p.legend(('1','2','3','4','5'),loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
p.set_title('FAMILY')
p.set_ylabel('Length of review')

fin = temp[(temp.category == 'FINANCE')].groupby(["new_date","score"])[['len']].mean().unstack('score')
p= fin.plot()
p.legend(('1','2','3','4','5'),loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
p.set_title('FINANCE')
p.set_ylabel('Length of review')

game = temp[(temp.category == 'GAME_ACTION')].groupby(["new_date","score"])[['len']].mean().unstack('score')
p= game.plot()
p.legend(('1','2','3','4','5'),loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
p.set_title('GAME_ACTION')
p.set_ylabel('Length of review')

haf = temp[(temp.category == 'HEALTH_AND_FITNESS')].groupby(["new_date","score"])[['len']].mean().unstack('score')
p= haf.plot()
p.legend(('1','2','3','4','5'),loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
p.set_title('HEALTH_AND_FITNESS')
p.set_ylabel('Length of review')

life = temp[(temp.category == 'LIFESTYLE')].groupby(["new_date","score"])[['len']].mean().unstack('score')
p= life.plot()
p.legend(('1','2','3','4','5'),loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
p.set_title('LIFESTYLE')
p.set_ylabel('Length of review')

maa = temp[(temp.category == 'MUSIC_AND_AUDIO')].groupby(["new_date","score"])[['len']].mean().unstack('score')
p= maa.plot()
p.legend(('1','2','3','4','5'),loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
p.set_title('MUSIC_AND_AUDIO')
p.set_ylabel('Length of review')
# Out:
# Text(0, 0.5, 'Length of review')

# %% [markdown]
# From the plot, we could hardly find any pattern for length of review changes, which make senece, because the length of review of app-category should not be affected by the date.
#     For the scores, we could find that no matter in which date, lower score would always have higher average text length, in the graph, line for scoer 1,2 and 3 are always higher than lines for score 4 and 5.

# %% [markdown]
# ### Manual evaluation.
# Use the dataset of the output of Text Pre-processing section in this section.
# From each app category, randomly select 25 reviews such that there are 5 reviews from each of the scores.
# For example, you should select five reviews that have score of 1, five reviews with score of 2, and so on.
# Save these reviews with all of the columns (app name, score, text, etc.) in a csv/excel file. Create two
# more columns named as Sentiment and Constructive/Detailed. Read the text of the reviews and assign a
# score to each of the Sentiment or Constructive as follows.
# - Sentiment has a score between -5 to 5. The -5 means that review is a negative comment, +5 being
# the positive comment, and zero as a neutral text.
# - Constructive score is a score between 0 to 10 and identifies how useful and constructive a feedback
# is. For example, a comment that mentions “The app crashes all the time” is not constructive, as it
# does not provide any details about the problem opposed to “The app crashes when I click on
# camera”. Constructive score 0 means that the feedback does not provide any useful information
# for the developers to improve the app, and 10 means that the details about the issues or requested
# features are discussed.

# %%
process = pd.read_csv("preprocess.csv")

# %%
import numpy as np
temp = process.copy()
g = temp.groupby(['category', 'score'])
blocks = [what.sample(n=5) for _,what in g]
manual = pd.concat(blocks)

# %%
manual.to_csv('manual.csv',index="False")

# %% [markdown]
# 19. Compare your scores among the app categories. Do you see a difference between app categories?
#
# Answered in last block, my anser sheet.

# %%
manual1 = pd.read_csv("manual_copy.csv",encoding='unicode_escape')

# %%
tempt = manual1.copy()
tempt["sentiment"]= tempt["sentiment"].astype(int)
sentiment = tempt.groupby(["category"]).sentiment.value_counts().unstack('category')
sentiment.plot(kind='bar', stacked=False).legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)

# %%
tempt["constructive"]= tempt["constructive"].astype(int)
constructive = tempt.groupby(["category"]).constructive.value_counts().unstack('category')
constructive.plot(kind='bar', stacked=False).legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)

# %% [markdown]
# # my answer sheet
# ##### 1. Drop duplicates and record how many unique reviews are collected?
#
#     After droping duplicates, we get 1478938 reviews left.
#
#
#  ##### 2. How many unique apps are in the dataset? How many apps in each of the 8 specified app categories?
#
#     There are 87 unique apps in the dataset.
#
#     The number of apps in each of the 8 specified apps are:
#
# ![title](q2.JPG)
#
#  ##### 3. How many reviews exist in each of the eight app-categories?
#
#     Number of reviews in each of the eight app-categories:
#
# ![title](q3.JPG)
#
#  ##### 4. Based on the contentRating column in the details files for each app, what are the different contentRating groups in each app-category?
#
#     The different contentRating groups in each app-category are:
#
# ![title](q4.JPG)
#
#  ##### 5. How many apps exist in each of these contentRating-sub-groups in each app-category?
#
#     Number of apps in each of contentRating-sub groups in each app-category are:
#
# ![title](q5.JPG)
#
#  ##### 6. How many reviews in each contentRating-sub-groups in each app-category?
#
#     The number of reviews in each contentRating sub group in each app category are:
#
# ![title](q6.JPG)
#
#  ##### 7. Should we remove the reviews that contain two or less number of words?
#
#     a. Justify your answers.
#
#     a) Yes we should remove the reviews that contain two or less number of words. Because it would not provide any meaningful information if the lenth of the comment is too short.
#
#     b. Can we remove the reviews with two or less words for some score-sub-groups and keep them in the other ones? E.g. if the review has score 1, we should remove such reviews, but we should keep them if the rating is 5. Justify your answers.
#
#     b) We should not only remove the reviews with two or less words for some score-sub-groups and keep them in the other ones. I think we should apply this to all scores-sub categories because the less than two words comment would always not being able to convey constructive suggestions no matter what scores-sub categories that comment is in.evaluations on the app.
#
#
#  ##### 8. How many reviews exist in each of the eight app-categories? Compare with question 3.
#
#     Number of reviews in each of the eight app-categories for question 8:
#
# ![title](q8.JPG)
#
#     while the number of revies in each of the eight app-category for question 3:
#
# ![title](q3.JPG)
#
# ![title](q8_answer.JPG)
#     From the comparision we could see that, the number of reviews in each of the eight app-category largely drops after we preprocess our data, For each category, the reviews drops in average ratio of 1/ 1.5822561390371601 of original reviews
#
#
#  ##### 9. How many reviews in each contentRating-sub-groups in each app-category? Compare with question 6.
#     Number of reviews in each contentRating-sub-groups in each app-category after text pre-process is:
#
# ![title](q9.JPG)
#
#     while the number of reviews in each content-rating sub groups in each app category for questin 6 is:
#
# ![title](q6.JPG)
#
#     From the comparision we could see that, the number of reviews in each content-rating sub groups in each app category also largely drops after we preprocess our data. For each contentRating-sub-groups in each app-category, the reviews drops in average ratio of 1/ 1.630532989300242 of original reviews
#
#  ##### 10. What is the number of reviews for each score (score column)? For example, 35000 reviews have a score of 1, etc.
#
#     THE number of reviews for each score for each app-category is:
#
# ![title](q10.JPG)
#
#  ##### 11. How many apps exist in each score-sub-group?
#
#     The number of apps exists in each score-sub-group is :
#
# ![title](q11.JPG)
#
#  ##### 12. Compare the number of reviews for each score in a plot (Remember to normalize the numbers when you are comparing them).
#
#     The bar plot for number of reviews for each score in each app-cateogory:
# ![title](q12_1.JPG)
# ![title](q12_2.JPG)
# ![title](q12_3.JPG)
# ![title](q12_4.JPG)
#
#
#     From each plot, we could see the general trend for number of reviews for each score, The score 5 would have the most and far mrore number of reviews than other scores, the score 1 is always the second most and score 2 always the least.
#
#  ##### 13. What is the average length of the reviews in each score-sub-group?
#     The average length of the reviews in each score sub group is:
# ![title](q13_1.JPG)
# ![title](q13_2.JPG)
#
#     Compare the result from this question and the previous question, we couls see that even though score 5 tends to have more reviews, people tend to leave shorter reviews for score 5 apps, and longer length of reviews for score 1,2,3.
#
#  ##### 14. Compare the average length of reviews in each score-sub-group in the 8 app categories (draw a plot).
#
# ![title](q14.JPG)
#
#     In terms of different categories,  from the above plot, we could see that the health and fitness category has the longest average-length and game action category have the shortest average length.
#
#     And in terms of the score, we find that people tend to write longer comments if they are unsatisfied about the app, in other words, the apps that rate low score. Which makes sense if we think about reality. In the complains, people, tend to mention the features that have problems or unsatisfied with, for future improvements and thus leads to longer comments.
#
#  ##### 15. Compare the number of reviews in each score-sub-group in the 8 app categories (draw a plot).
#
# ![title](q15.JPG)
#
#     In terms of different categories, we find that the game action tends to have most numbers of higher score reviews, which is corresponding to the minimum length in the reviews from the previous finding. On the contrary, the lifestyle category tends to have the most number of low score reviews.
#
#     And in terms of scores, we find that there are drastically far more 5 scores than the other scores reviews and 1 score numbers are also more than score2,3 and 4.
#
#
#  ##### 16. Compare the number of apps in each score-sub-group in the 8 app categories (draw a plot).
#
# ![title](q16.JPG)
#
#     Because the number of apps in each of the 8 specified app categories remained same for whatever the score is, as shown in question 2, as follows:
#
# ![title](q2.JPG)
#
#     The bar would have same length in bar plot for each score.
#
#  ##### 17. Is there any correlation between the length of the reviews and the score in each app-category?
#      The correlation between length of the review and the score in each app-category could was very small (nearly 0), which means there is almost no correlation between the length of the reviews and the score in each app-category.
# ![title](q17.JPG)
#
#      The heatmap for the correlation looks like this, more specifically, the pinkc block in the graph.
# ![title](q17_1.JPG)
#
#  ##### 18. Find the evolution/changes of the star rating and length of reviews during time for each app category. Draw plots.
#     a. Can we use the date column for this question?
#
#     a) we cannot use the date column for this question, because the date in date column are not unify, it has date from different day, month or even year.
#
#
#     b. If not, what is the solution based on the data you have?
#
#     b) from the data we have, we can extract the date from the filename as new_date and add as a column, using that date for analysis.
#
#     The plot below shows the changes of length of reviews during time for each app category for eachh score. The x-axis is the dates, y axis is teh length of the reivew, legend is for each score.
# ![title](q18_1.JPG)
# ![title](q18_2.JPG)
# ![title](q18_3.JPG)
# ![title](q18_4.JPG)
#
#     From the plot, we could hardly find any pattern for length of review changes, which make senece, because the length of review of app-category should not be affected by the date.
#     For the scores, we could find that no matter in which date, lower score would always have higher average text length, in the graph, line for scoer 1,2 and 3 are always higher than lines for score 4 and 5.
#
#
# ##### 19. Compare your scores among the app categories. Do you see a difference between app categories?
#      from the 200 samples, we could plot the number of sentiment scores and constructive/detailed scores for each such-score-category of each app-category.
#      sentiment:
# ![title](q19_1.JPG)
#
#     The graph shows for the 200 samples, game_action category, family, and entertainment category tends to have more positive comments while finance and lifes tyle in this 200 samples tend to more negative numbers of comments
#
#      constructive:
# ![title](q19_2.JPG)
#
#      The graph shows that there are only small number of constructive comments which could help developer to improve the app. And from those 200 samples, the game action category seems to have the least constructive review numbers while music_and_audio and entertainment seems to have more numbers of constructive reviews.
